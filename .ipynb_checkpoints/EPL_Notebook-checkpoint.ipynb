# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

from wrangle import epl_aq_all
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Wrangle Data
# Three functions acquiring and prepping data are all available in wrangle.py file.
# - 1. `epl_year_aq`: pulls in data frame from season
# - 2. `strip_team_name`: takes in season csv and splits and cleans team_name_column
# - 3. `epl_aq_all`: creates df of all seasons of epl
# - 4. `rename columns`: renamess columns explicitly

# %%
df = epl_aq_all()

# %% [markdown]
# #### Overview of the dataframe

# %%
print(df.shape)
print(df.info())
df.head(2)
# Out:
# (340, 10)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 340 entries, 2002-01-01 to 2018-01-01
# Data columns (total 10 columns):
# team_name        340 non-null object
# games_played     340 non-null int64
# wins             340 non-null int64
# draws            340 non-null int64
# losses           340 non-null int64
# goals_for        340 non-null int64
# goals_against    340 non-null int64
# GD               340 non-null int64
# points           340 non-null int64
# place            340 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 29.2+ KB
# None
#                     team_name  games_played  wins  draws  losses  goals_for  \
# year
# 2002-01-01  Manchester United            38    25      8       5         74
# 2002-01-01            Arsenal            38    23      9       6         85
#
#             goals_against  GD  points  place
# year
# 2002-01-01             34  40      83      1
# 2002-01-01             42  43      78      2

# %%
df.describe()
# Out:
#        games_played        wins       draws      losses   goals_for  \
# count         340.0  340.000000  340.000000  340.000000  340.000000
# mean           38.0   14.235294    9.529412   14.235294   50.758824
# std             0.0    6.023841    2.819394    5.595820   15.492335
# min            38.0    1.000000    2.000000    0.000000   20.000000
# 25%            38.0   10.000000    7.000000   10.000000   41.000000
# 50%            38.0   13.000000    9.000000   15.000000   47.000000
# 75%            38.0   18.000000   11.000000   18.000000   59.000000
# max            38.0   32.000000   17.000000   29.000000  106.000000
#
#        goals_against          GD      points      place
# count     340.000000  340.000000  340.000000  340.00000
# mean       50.758824    0.000000   52.208824   10.50000
# std        13.182430   25.948667   17.242002    5.77478
# min        15.000000  -69.000000   11.000000    1.00000
# 25%        41.750000  -18.250000   40.000000    5.75000
# 50%        51.000000   -7.000000   47.500000   10.50000
# 75%        59.000000   16.500000   63.000000   15.25000
# max        89.000000   79.000000  100.000000   20.00000

# %% [markdown]
# # Train-Test Split
# 1.  Initially we will take last two full years as test data
# 2.  After MVP we will start cross validation

# %%
train = df[:'2016']
test = df['2016':]

# %%
# 3 seasons for initial test:
train.shape, test.shape
# Out:
# ((300, 10), (60, 10))

# %% [markdown]
# # Explore

# %% [markdown]
# ### Team Results

# %%
train.groupby('team_name').points.plot()
plt.show()

# %%
train.points.hist()

# %%
train.draws.hist()

# %%
train.draws.mean()
# Out:
# 9.666666666666666

# %%
train.groupby('place').draws.mean().plot.bar()

# %%
train.groupby('place').draws.median().plot.bar()

# %%
train.groupby('place').points.median().plot.bar()

# %%
train[train.points <= 4].points.mean()
# Out:
# nan

# %%
plt.scatter(x='points', y = 'GD', data = train)

# %%
train.GD.hist()

# %%
sns.heatmap(train.corr(), cmap="YlGnBu", annot=True)

# %%
def assing_post_season(df):
    if df.place <= 4:
        df['post_season'] = 'champions_league'
    elif df.place <= 8:
        df['post_season'] = 'europa_league'
    elif df.place <= 14:
        df['post_season'] = 'mid_table'
    elif df.place <= 17:
        df['post_season'] = 'relegation_battle'
    else:
        df['post_season'] = 'relegation'
    return df
    

# train['post_season'] = train.place.apply()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-f0cd6c79eb93> in <module>
#      13
#      14
# ---> 15 train['post_season'] = train.place.apply()
#
# TypeError: apply() missing 1 required positional argument: 'func'

# %%
assing_post_season(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-8a907efb9ad3> in <module>
# ----> 1 assing_post_season(df)
#
# <ipython-input-92-f0cd6c79eb93> in assing_post_season(df)
#       1 def assing_post_season(df):
# ----> 2     if df.place <= 4:
#       3         df['post_season'] = 'champions_league'
#       4     elif df.place <= 8:
#       5         df['post_season'] = 'europa_league'
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
